# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Requirement already satisfied: getorg in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.3.1)
# Requirement already satisfied: geopy in /usr/local/python/3.12.1/lib/python3.12/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /usr/local/python/3.12.1/lib/python3.12/site-packages (from getorg) (2.5.0)
# Requirement already satisfied: retrying in /usr/local/python/3.12.1/lib/python3.12/site-packages (from getorg) (1.3.4)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from geopy->getorg) (2.0)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /home/codespace/.local/lib/python3.12/site-packages (from pygithub->getorg) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from pygithub->getorg) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pygithub->getorg) (2.2.3)
# Requirement already satisfied: Deprecated in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pygithub->getorg) (1.2.15)
# Requirement already satisfied: six>=1.7.0 in /home/codespace/.local/lib/python3.12/site-packages (from retrying->getorg) (1.17.0)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (44.0.0)
# Requirement already satisfied: cffi>=1.4.1 in /home/codespace/.local/lib/python3.12/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (2024.8.30)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from Deprecated->pygithub->getorg) (1.17.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.22)

# %%
g = "locations.txt"

# %%
geocoder = Nominatim()
location_dict = {}
location = ""
permalink = ""
title = ""
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 geocoder = Nominatim()
#       2 location_dict = {}
#       3 location = ""
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/geopy/geocoders/nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
#     110         'Please specify a custom `user_agent` with '
#     111         '`Nominatim(user_agent="my-application")` or by '
#     112         'overriding the default `user_agent`: '
#     113         '`geopy.geocoders.options.default_user_agent = "my-application"`.'
#     114         % self.headers['User-Agent']
#     115     )
#     117 self.api = "%s://%s%s" % (self.scheme, self.domain, self.geocode_path)
#     118 self.reverse_api = "%s://%s%s" % (self.scheme, self.domain, self.reverse_path)
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "geopy/2.4.1" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.

# %%
import getorg
from getorg.orgmap import create_map_obj, plot_points_on_map
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

def read_locations(file_path):
    """
    Reads a list of locations from a file.
    Each line in the file represents a location.

    :param file_path: Path to the file containing locations.
    :return: List of locations as strings.
    """
    try:
        with open(file_path, 'r') as file:
            locations = [line.strip() for line in file if line.strip()]
        return locations
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

def geocode_locations(locations):
    """
    Geocodes a list of locations to latitude and longitude.

    :param locations: List of location strings.
    :return: Dictionary of location names to (latitude, longitude).
    """
    geolocator = Nominatim(user_agent="geoapiExercises")
    location_dict = {}

    for loc in locations:
        try:
            geo_data = geolocator.geocode(loc, timeout=10)
            if geo_data:
                location_dict[loc] = (geo_data.latitude, geo_data.longitude)
            else:
                print(f"Warning: Could not geocode location '{loc}'")
        except GeocoderTimedOut:
            print(f"Warning: Geocoding timed out for location '{loc}'")
        except Exception as e:
            print(f"Error geocoding location '{loc}': {e}")

    return location_dict

def create_map_with_locations(location_dict):
    """
    Creates a map with the provided geocoded locations using the getorg library.

    :param location_dict: Dictionary of location names to (latitude, longitude).
    :return: None
    """
    if not location_dict:
        print("No valid locations provided to create the map.")
        return

    try:
        # Create the map
        m = create_map_obj()
        m = plot_points_on_map(m, location_dict)

        # Save the map
        output_path = "map.html"
        m.save(output_path)
        print(f"Map successfully created and saved as {output_path}")

    except Exception as e:
        print(f"An error occurred while creating the map: {e}")

def main():
    # Path to the file containing locations
    file_path = "locations.txt"  # Update with the actual file path

    # Read locations from the file
    locations = read_locations(file_path)

    # Geocode locations to get latitude and longitude
    location_dict = geocode_locations(locations)

    # Create the map with geocoded locations
    create_map_with_locations(location_dict)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 import getorg
# ----> 2 from getorg.orgmap import create_map_obj, plot_points_on_map
#       3 from geopy.geocoders import Nominatim
#       4 from geopy.exc import GeocoderTimedOut
#
# ImportError: cannot import name 'plot_points_on_map' from 'getorg.orgmap' (/usr/local/python/3.12.1/lib/python3.12/site-packages/getorg/orgmap.py)

# %%
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut


geocoder = Nominatim(user_agent="my_custom_application")
location_dict = {}
location = ""
permalink = ""
title = ""



with open("locations.txt", 'r') as f:
    locations = [line.strip() for line in f if line.strip()]
    for location in locations:
        location_dict[location] = geocoder.geocode(location, timeout=30)
        print(location, ": ", location_dict[location], "\n")


m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet
# Graz, Austria :  Graz, Steiermark, Österreich
#
# Vienna, Austria :  Wien, Österreich
#
# Tal, Austria :  Tal, Tragöß-Sankt Katharein, Bezirk Bruck-Mürzzuschlag, Steiermark, 8612, Österreich
#
# Hallstatt, Austria :  Hallstatt, Bezirk Gmunden, Region Traunviertel (NUTS), Oberösterreich, 4830, Österreich
#
# Bruck an der Mur, Austria :  Bruck an der Mur, Bezirk Bruck-Mürzzuschlag, Steiermark, 8600, Österreich
#
# Obertraun, Austria :  Obertraun, Bezirk Gmunden, Region Traunviertel (NUTS), Oberösterreich, 4831, Österreich
#
# Klagenfurt, Austria :  Klagenfurt am Wörthersee, Kärnten, Österreich
#
# Antwerp, Belgium :  Antwerpen, Vlaanderen, België / Belgique / Belgien
#
# Leuven, Belgium :  Leuven, Vlaams-Brabant, Vlaanderen, België / Belgique / Belgien
#
# Brussels, Belgium :  Bruxelles - Brussel, Brussel-Hoofdstad - Bruxelles-Capitale, Région de Bruxelles-Capitale - Brussels Hoofdstedelijk Gewest, België / Belgique / Belgien
#
# Schaerbeek, Belgium :  Schaerbeek - Schaarbeek, Brussel-Hoofdstad - Bruxelles-Capitale, Région de Bruxelles-Capitale - Brussels Hoofdstedelijk Gewest, België / Belgique / Belgien
#
# Louvain-la-Neuve, Belgium :  Louvain-la-Neuve, Ottignies-Louvain-la-Neuve, Nivelles, Brabant wallon, Wallonie, 1348, België / Belgique / Belgien
#
# Blankenberge, Belgium :  Blankenberge, Brugge, West-Vlaanderen, Vlaanderen, 8370, België / Belgique / Belgien
#
# Ghent, Belgium :  Gent, Oost-Vlaanderen, Vlaanderen, België / Belgique / Belgien
#
# Turnhout, Belgium :  Turnhout, Antwerpen, Vlaanderen, 2300, België / Belgique / Belgien
#
# Bruges, Belgium :  Brugge, West-Vlaanderen, Vlaanderen, België / Belgique / Belgien
#
# Phnom Penh, Cambodia :  រាជធានីភ្នំពេញ, ព្រះរាជាណាចក្រ​កម្ពុជា
#
# Hekou, China :  河口瑶族自治县, 红河哈尼族彝族自治州, 云南省, 中国
#
# Zagreb, Croatia :  Grad Zagreb, Hrvatska
#
# Breclav, Czechia :  Břeclav, okres Břeclav, Jihomoravský kraj, Jihovýchod, Česko
#
# Mikulov, Czechia :  Mikulov, okres Břeclav, Jihomoravský kraj, Jihovýchod, 692 01, Česko
#
# Brno, Czechia :  Brno, okres Brno-město, Jihomoravský kraj, Jihovýchod, Česko
#
# Prague, Czechia :  Praha, obvod Praha 4, Hlavní město Praha, Praha, Česko
#
# Dresden, Germany :  Dresden, Sachsen, Deutschland
#
# Frankfurt, Germany :  Frankfurt am Main, Hessen, Deutschland
#
# Potsdam, Germany :  Potsdam, Brandenburg, Deutschland
#
# Brandenburg, Germany :  Brandenburg, Deutschland
#
# Fira, Greece :  Φηρά, Δημοτική Ενότητα Θήρας, Δήμος Θήρας, Περιφερειακή Ενότητα Θήρας, Περιφέρεια Νοτίου Αιγαίου, Αποκεντρωμένη Διοίκηση Αιγαίου, 847 00, Ελλάς
#
# Oia, Greece :  Οία, Δημοτική Ενότητα Οίας, Δήμος Θήρας, Περιφερειακή Ενότητα Θήρας, Περιφέρεια Νοτίου Αιγαίου, Αποκεντρωμένη Διοίκηση Αιγαίου, 847 02, Ελλάς
#
# Athens, Greece :  Αθήνα, Δήμος Αθηναίων, Περιφερειακή Ενότητα Κεντρικού Τομέα Αθηνών, Περιφέρεια Αττικής, Αποκεντρωμένη Διοίκηση Αττικής, 105 57, Ελλάς
#
# Budapest, Hungary :  Budapest, Közép-Magyarország, Magyarország
#
# Batam, Indonesia :  Batam, Kepulauan Riau, Sumatera, Indonesia
#
# Rome, Italy :  Roma, Roma Capitale, Lazio, Italia
#
# Venice, Italy :  Venezia, Veneto, 30121-30176, Italia
#
# Milan, Italy :  Milano, Lombardia, Italia
#
# Perlerdo, Italy :  None
#
# Bellangio, Italy :  None
#
# Varenna, Italy :  Varenna, Lecco, Lombardia, 23829, Italia
#
# Vientiane, Laos :  ວຽງຈັນ, ເມືອງຈັນທະບູລີ, ນະຄອນຫຼວງວຽງຈັນ, ປະເທດລາວ
#
# Luxembourg, Luxembourg :  Luxembourg, Canton Luxembourg, Lëtzebuerg
#
# Malacca, Malaysia :  Melaka, Malaysia
#
# Kuala Lumpur, Malaysia :  Kuala Lumpur, Malaysia
#
# Johor Bahru, Malaysia :  Johor Bahru, Johor, 80730, Malaysia
#
# Sliema, Malta :  Tas-Sliema, Ċentrali, Malta
#
# Msida, Malta :  L-Imsida, Ċentrali, Malta
#
# Valletta, Malta :  Valletta, Xlokk, Malta
#
# Rabat, Malta :  Ir-Rabat, Tramuntana, Malta
#
# Qrendi, Malta :  Il-Qrendi, Nofsinhar, QRD 3043, Malta
#
# Monaco, Monaco :  Monaco
#
# Leiden, Netherlands :  Leiden, Zuid-Holland, Nederland
#
# Amsterdam, Netherlands :  Amsterdam, Noord-Holland, Nederland
#
# The Hague, Netherlands :  Den Haag, Zuid-Holland, Nederland
#
# Lisse, Netherlands :  Lisse, Zuid-Holland, Nederland
#
# Warsaw, Poland :  Warszawa, województwo mazowieckie, Polska
#
# Krakow, Poland :  Kraków, województwo małopolskie, Polska
#
# Lisbon, Portugal :  Lisboa, Portugal
#
# Sintra, Portugal :  Sintra, Lisboa, Portugal
#
# Cascais, Portugal :  Cascais, Lisboa, Portugal
#
# Singapore, Singapore :  Singapore
#
# Bratislava, Slovakia :  Bratislava, Bratislavský kraj, Slovensko
#
# Maribor, Slovenia :  Maribor, Slovenija
#
# Ljubbljana, Slovenia :  None
#
# Bled, Slovenia :  Bled, Slovenija
#
# Blejska Dobrava, Slovenia :  Blejska Dobrava, Jesenice, 4273, Slovenija
#
# Barcelona, Spain :  Barcelona, Barcelonès, Barcelona, Catalunya, España
#
# Frontera del Portalet, Spain :  Frontera del Portalet, Sallent de Gállego, Alto Gállego, Huesca, Aragón, España
#
# Lausanne, Switzerland :  Lausanne, District de Lausanne, Vaud, Schweiz/Suisse/Svizzera/Svizra
#
# Bern, Switzerland :  Bern, Verwaltungskreis Bern-Mittelland, Verwaltungsregion Bern-Mittelland, Bern/Berne, Schweiz/Suisse/Svizzera/Svizra
#
# Belp, Switzerland :  Belp, Verwaltungskreis Bern-Mittelland, Verwaltungsregion Bern-Mittelland, Bern/Berne, Schweiz/Suisse/Svizzera/Svizra
#
# Brienz, Switzerland :  Brienz (BE), Verwaltungskreis Interlaken-Oberhasli, Verwaltungsregion Oberland, Bern/Berne, Schweiz/Suisse/Svizzera/Svizra
#
# Interlaken, Switzerland :  Interlaken, Verwaltungskreis Interlaken-Oberhasli, Verwaltungsregion Oberland, Bern/Berne, 3800, Schweiz/Suisse/Svizzera/Svizra
#
# Spiez, Switzerland :  Spiez, Verwaltungskreis Frutigen-Niedersimmental, Verwaltungsregion Oberland, Bern/Berne, Schweiz/Suisse/Svizzera/Svizra
#
# Grindelwald, Switzerland :  Grindelwald, Verwaltungskreis Interlaken-Oberhasli, Verwaltungsregion Oberland, Bern/Berne, 3818, Schweiz/Suisse/Svizzera/Svizra
#
# Lauterbrunnen, Switzerland :  Lauterbrunnen, Verwaltungskreis Interlaken-Oberhasli, Verwaltungsregion Oberland, Bern/Berne, Schweiz/Suisse/Svizzera/Svizra
#
# Thun, Switzerland :  Thun, Verwaltungskreis Thun, Verwaltungsregion Oberland, Bern/Berne, Schweiz/Suisse/Svizzera/Svizra
#
# Lucerne, Switzerland :  Luzern, Schweiz/Suisse/Svizzera/Svizra
#
# Arth, Switzerland :  Arth, Schwyz, Schweiz/Suisse/Svizzera/Svizra
#
# Zurich, Switzerland :  Zürich, Bezirk Zürich, Zürich, Schweiz/Suisse/Svizzera/Svizra
#
# Geneva, Switzerland :  Genève, Schweiz/Suisse/Svizzera/Svizra
#
# Taipei, Taiwan :  臺北市, 臺灣
#
# Bangkok, Thailand :  กรุงเทพมหานคร, ประเทศไทย
#
# Hanoi, Vietnam :  Thành phố Hà Nội, Việt Nam
#
# Thai Nguyen, Vietnam :  Tỉnh Thái Nguyên, Việt Nam
#
# Nam Dinh, Vietnam :  Tỉnh Nam Định, Việt Nam
# 'Written map to ../talkmap/'

# %%
len(location_dict)
# Out:
# 1

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
